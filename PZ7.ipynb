# %% [markdown]
# <a href="https://colab.research.google.com/github/Chris02374/Kashin-IS-27/blob/main-kashin/PZ7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ПЗ 7: Вариант 8
#
# 1. Дано целое число N (>0) и символ C. Вывести строку длины N, которая состоит из символов C.
#
# 2. Дана строка-предложение с избыточными пробелами между словами. Преобразовать ее так, чтобы между словами был ровно один пробел.

# %%
n = input("Введите целое число N (>0): ")

while type(n) != int:
    try:
        n = int(n)
    except ValueError:
        print("Неправильно ввели!")
        n = input("Введите целое число N (>0): ")
if n <= 0:
    print("Ошибка: N должно быть больше 0")
else:
    c = input("Введите символ C: ")

    while len(c) != 1:
        print("Ошибка: нужно ввести ровно один символ!")
        c = input("Введите символ C: ")
    result = c * n
    print(f"Результат: '{result}'")
    print(f"Длина строки: {len(result)}")
# Out:
# Введите целое число N (>0): 5
# Введите символ C: 2
# Результат: '22222'
# Длина строки: 5

# %%
predlozhenie = input("Введите строку-предложение: ")
predlozhenie = predlozhenie.strip()

if len(predlozhenie) == 0:
    print("Ошибка: строка пустая")
else:
    print(f"Исходная строка: '{predlozhenie}'")

    slova = predlozhenie.split()

    result = ' '.join(slova)

    print(f"Результат: '{result}'")

    original_spaces = predlozhenie.count(' ')
    result_spaces = result.count(' ')
    spaces_removed = original_spaces - result_spaces

    print(f"Убрано лишних пробелов: {spaces_removed}")
# Out:
# Введите строку-предложение: 5
# Исходная строка: '5'
# Результат: '5'
# Убрано лишних пробелов: 0
